# %% [markdown]
# Elabore um programa que leia um número inteiro e imprima se ele é par ou ímpar

# %%
a = int(input("Digite um número inteiro: "))

if a % 2 == 0:
    print(f"O número {a} é par")
else: 
    print(f"O número {a} é ímpar")
# Out:
# O número 11 é ímpar

# %% [markdown]
# Construa um programa que leia os lados de um quadrilátero e determine se é um Quadrado ou um Retângulo

# %%
lado_1 = float(input("Digite o primeiro lado do quadrilátero: "))
lado_2 = float(input("Digite o segundo lado do quadrilátero: "))

if lado_1 == lado_2: 
    print("O quadrilátero é quadrado")
else:
    print("O quadrilátero é retângulo")
# Out:
# O quadrilátero é retângulo

# %% [markdown]
# Faça um Programa que peça dois números e imprima o maior deles

# %%
n1 = float(input("Digite o primeiro número: "))
n2 = float(input("Digite o segundo número: "))

if n1 > n2:
    print(f"O número {n1} é maior que o {n2}")
else:
    print(f"O número {n2} é maior que o {n1}")
# Out:
# O número 2.0 é maior que o 1.0

# %% [markdown]
# Faça um Programa que peça um valor e mostre na tela se o valor é positivo, negativo ou nulo

# %%
n3 = float(input("Digite um número: "))

if n3 > 0:
    print(f"O número é positivo")
elif n3 == 0:
    print(f"O número é nulo")
else:
    print(f"O número é negativo")
# Out:
# O número é positivo

# %% [markdown]
# Crie um algoritmo que receba do usuário um número qualquer e verifique se esse é múltiplo de 5

# %%
n4 = float(input("Digite um número: "))

if n4 % 5 == 0:
    print("O número é múltiplo de 5")
else:
    print("O número não é múltiplo de 5")
# Out:
# O número é múltiplo de 5

# %% [markdown]
# Construir um programa que faz a leitura de dois valores inteiros A e B. Se os valores forem iguais deverá somar os dois, caso contrário multiplique A por B.
# Ao final de qualquer um dos cálculos deve-se atribuir o resultado para uma variável C e mostrar seu conteúdo na tela

# %%
a = int(input("Digite o primeiro valor: "))
b = int(input("Digite o segundo valor:"))

if a == b: 
    c = a + b
    print(f"Os valores são iguais, logo a soma é igual a {c}")
else: 
    c = a * b
    print(f"Os valores são diferentes, logo a multiplicação é igual a {c}")
# Out:
# Os valores são diferentes, logo a multiplicação é igual a 6

# %% [markdown]
# Um funcionário irá receber um aumento de acordo com o seu plano de trabalho, de acordo com a tabela abaixo:
#
# 1 = 10%,
# 2 = 15%,
# 3 = 20%
#
# Faça um programa que leia o plano de trabalho e o salário atual de um funcionário e calcula e imprime o seu novo salário

# %%
salario_atual = float(input("Digite o seu salário atual: "))
plano_trabalho = int(input("Digite o seu plano de trabalho (1, 2 ou 3): "))

if plano_trabalho == 1:
    novo_salario = (salario_atual * 0.10) + salario_atual
    print(f"Como o seu plano é o 1, seu novo salário será de R$ {novo_salario}")

elif plano_trabalho == 2:
    novo_salario = (salario_atual * 0.15) + salario_atual
    print(f"Como o seu plano é o 2, seu novo salário será de R$ {novo_salario}")

elif plano_trabalho == 3:
    novo_salario = (salario_atual * 0.20) + salario_atual
    print(f"Como o seu plano é o 3, seu novo salário será de R$ {novo_salario}")

else:
    print("O plano digitado não se encaixa em nenhum dos reajustes disponíveis, verifique e tente novamente")
# Out:
# O plano digitado não se encaixa em nenhum dos reajustes disponíveis, verifique e tente novamente

# %% [markdown]
# Escreva um programa que calcule x elevado a n. Considere que n é um valor inteiro não negativo. PROIBIDO USAR QUALQUER FUNÇÃO MATEMATICA EXISTENTE no PYTHON, incluindo **

# %%
x = float(input("Digite a base: "))
n = int(input("Digite o expoente (não nulo e não negativo):"))

resultado = 1
contador = 0

if n <= 0: 
    resultado = 1
else: 
    while contador < n:
        resultado = resultado * x
        contador = contador + 1

print("Resultado: ", resultado)
# Out:
# Resultado:  8.0

# %% [markdown]
# Faça um programa que imprima os números inteiros de 100 a 450, que são múltiplos de 7

# %%
for i in range(100, 451):
    if i % 7 == 0: 
        print(i)

# %% [markdown]
# Escreva um algoritmo que leia n de números inseridos pelo usuário (n é fornecido pelo usuário) e realize a soma dos números pares e conta quantos impares o usuário digitou. O resultado da
# soma dos pares e o número de ímpares digitados deverá ser impresso no final

# %%
n = int(input("Insira a quantidade de números que deseja inserir: "))

contador_impar = 0
soma_par = 0

for i in range (n):
    num = int(input(f"Digite o {i+1}º número: "))

    if i % 2 == 0: 
        soma_par += num
    else:
        contador_impar += 1 

print(f"A quantidade de impares digitados foi de {contador_impar} e a soma dos pares é {soma_par}")
# Out:
# A quantidade de impares digitados foi de 2 e a soma dos pares é 9

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
while 1:

    a= float(input("Digite o valor A: "))
    b= float(input("Digite o valor B: "))
    c= float(input("Digite o valor C: "))
    d= float(input("Digite o valor D: "))
    e= float(input("Digite o valor E: "))
    f= float(input("Digite o valor F: "))

    if a and b and c and d and e and f < 0:
        print("Fim do programa")
        break

    denominador = (a * e - b * d) 

    if denominador == 0:
        print("O sistema não pode ser dividido por 0")
        break
    else:
        x = (c * e - b * f) / denominador
        y = (a * f - c * d) / denominador
        print(f"A solução do sistema é igual: x = {x:.2f}, y = {y:.2f}")
        break
# Out:
# A solução do sistema é igual: x = -1.00, y = 2.00

# %% [markdown]
# Construir um programa que faz a leitura de duas notas de um aluno, N1 e N2, e os respectivos pesos, P1 e P2. O programa deve calcular a média ponderada alcançada por aluno e apresentar:
#
# • A mensagem "Aprovado", se a média alcançada for maior ou igual a sete;
#
# • A mensagem "Reprovado", se a média for menor do que sete;
#
# • A mensagem "Aprovado com Distinção", se a média for igual a dez.

# %%
#sem while

n1 = float(input("Digite a nota 1 do aluno: "))
n2 = float(input("Digite a nota 2 do aluno: "))
p1 = int(input("Digite o peso 1 da nota:"))
p2 = int(input("Digite o peso 2 da nota: "))

media_ponderada = ((n1 * p1) + (n2 * p2)) / (p1 + p2) 

if media_ponderada == 10: 
    print("Aprovado com Distinção")
else:
    if media_ponderada >= 7: 
        print("Aprovado")
    else:
        print("Reprovado")
# Out:
# Reprovado

# %%
qtd_alunos = int(input("Insira a quantidade de alunos que deseja calcular a média: "))

for i in range (qtd_alunos):

    n1 = float(input("Digite a nota 1 do aluno: "))
    n2 = float(input("Digite a nota 2 do aluno: "))
    p1 = int(input("Digite o peso 1 da nota:"))
    p2 = int(input("Digite o peso 2 da nota: "))

    media_ponderada = ((n1 * p1) + (n2 * p2)) / (p1 + p2) 

    if media_ponderada == 10: 
        print("Aprovado com Distinção")
    else:
        if media_ponderada >= 7: 
            print("Aprovado")
        else:
            print("Reprovado")
# Out:
# Aprovado com Distinção
# Reprovado
# Aprovado
# Aprovado
# Reprovado

# %% [markdown]
# Construir um programa que faz a leitura de três número inteiros e imprime o maior

# %%
n1 = int(input("Digite o 1º número inteiro: "))
n2 = int(input("Digite o 2º número inteiro: "))
n3 = int(input("Digite o 3º número inteiro: "))

if n1 > n2 and n1 > n3:
    print("N1 maior")
elif n2 > n1 and n2 > n3:
    print("N2 maior")
else:
    print("N3 maior")
# Out:
# N2 maior

# %% [markdown]
# Fazer um programa que calcule o valor de N! (fatorial de N), sendo que o valor inteiro de N deve ser lido. Lembrando que:
#
# • N! = 1 x 2 x 3 x .... x (N – 1) x N;
#
# • 0! = 1, por definição

# %%
N = int(input("Digite um número para ser fatorado"))

resultado = 1

if N == 0: 
    resultado = 1
else:
    for i in range(1, N+1):
         resultado *= i
print(f"O fatorial de {N} é igual a {resultado}")
# Out:
# O fatorial de 10 é igual a 3628800

# %% [markdown]
# Fazer um programa que faz a leitura consecutiva de N números inteiros x. Construir um programa que identifica e imprime o MAIOR e o MENOR número entre os números digitados. O valor de N também deve ser digitado e deve ser maior ou igual a 10.

# %%
N = int(input("Digite o número de elementos (N) a serem digitados (deve ser maior ou igual a 10): "))

if N < 4:
    print("O valor de (N) deve ser maior ou igual a 10")
else:
    maior = None
    menor = None

    for i in range(N):
        x = int(input(f"Digite o número {i+1}: "))

        if maior is None or x > maior:
            maior = x
        if menor is None or x < menor:
            menor = x

    print(f"O maior número foi {maior}")
    print(f"O menor número foi {menor}")
# Out:
# O maior número foi 55
# O menor número foi -8

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = int(input("Digite um número inteiro: "))

soma = 0

for i in range (1, x, 1):
    if i % 7 == 0:
        soma += i
print(f"A soma dos múltiplos de 7 nessa sequência é igual a {soma}")
# Out:
# A soma dos múltiplos de 7 nessa sequência é igual a 42

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input("Digite a quantidade de números que você deseja inserir: "))

mult_10 = 0
soma_13 = 0
contador = 0

while contador < n:
    valor_digitado = int(input(f"Digite o valor: "))

    if valor_digitado % 10 == 0 and valor_digitado > mult_10:
        mult_10 = valor_digitado
    
    if valor_digitado % 13 == 0:
        soma_13 += valor_digitado

    contador += 1

print(f"O maior múltiplo de 10 digitado foi {mult_10}, a soma dos múltiplos de 13 é {soma_13}")
# Out:
# O maior múltiplo de 10 digitado foi 20, a soma dos múltiplos de 13 é 39

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
salario_atual = float(input("Digite o seu salário atual: "))

if salario_atual <= 980: 
    novo_salario = (salario_atual * 0.20) + salario_atual
    percentual_aumento = 0.20

elif salario_atual > 980 and salario_atual < 1500: 
    novo_salario = (salario_atual * 0.15) + salario_atual
    percentual_aumento = 0.15

elif salario_atual > 1500 and salario_atual < 2100: 
    novo_salario = (salario_atual * 0.10) + salario_atual
    percentual_aumento = 0.10

else:
    novo_salario = (salario_atual * 0.05) + salario_atual
    percentual_aumento = 0.05

print(f"\nSalário antes do reajuste: R$ {salario_atual}")
print(f"\nPercentual aplciado: {percentual_aumento * 100}%")
print(f"\nValor do aumento: R$ {novo_salario - salario_atual}")
print(f"\nNovo salário após o aumento: R$ {novo_salario}")
# Out:
# Salário antes do reajuste: R$ 2200.0
#
# Percentual aplciado: 5.0%
#
# Valor do aumento: R$ 110.0
#
# Novo salário após o aumento: R$ 2310.0
